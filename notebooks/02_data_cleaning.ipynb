# %% [markdown]
# # Data Cleaning
#
# Clean and preprocess the raw data.

# %%
# Standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Project imports
import sys
sys.path.append('..')
from src.data_processing import load_data, save_data, quick_clean
from src.visualization import save_figure
from project_setup import DataManager
# %matplotlib inline
sns.set_theme(style='whitegrid')

# %% [markdown]
# ## Load Data

# %%
# Load your data here
dm = DataManager()
df = dm.load('../data/raw/HousingPriceDataSet.csv')
df.head()
# Out:
# 📂 File: HousingPriceDataSet.csv
# 🔍 Detected encoding: ascii (100.0%)
# ✅ Loaded 546 rows × 13 columns
#    indexcore    price  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0          1  42000.0     5850         3        1        2      yes      no
# 1          2  38500.0     4000         2        1        1      yes      no
# 2          3  49500.0     3060         3        1        1      yes      no
# 3          4  60500.0     6650         3        1        2      yes     yes
# 4          5  61000.0     6360         2        1        1      yes      no
#
#   fullbase gashw airco  garagepl prefarea
# 0      yes    no    no         1       no
# 1       no    no    no         0       no
# 2       no    no    no         0       no
# 3       no    no    no         0       no
# 4       no    no    no         0       no

# %%
df_clean = quick_clean(df)
# Out:
# 🧹 QUICK CLEANING
# ...
# ✓ No duplicates found
#
#  📊 Shape: (546, 13) → (546, 13)
#    Removed: 0 rows (0.0%)
# ...

# %%
dm = DataManager()
df = dm.quick_clean(df, remove_duplicates=True, convert_dates=None, save_path="../data/processed/cleaned_data.csv")
# Out:
# 🧹 CLEANING DATA
# ...
# ✓ Dropped 0 rows with missing values
# ✅ Saved 546 rows to ..\data\processed\cleaned_data.csv
#
# 📊 Shape: (546, 13) → (546, 13)
#    Removed: 0 rows (0.0%)
# ...
