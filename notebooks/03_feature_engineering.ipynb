# %% [markdown]
# # Feature Engineering
#
# Create and transform features for modeling.

# %%
# Standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append('..')
from project_setup import FeatureEngineer, DataManager,Visualizer
# %matplotlib inline
sns.set_theme(style='whitegrid')

# %% [markdown]
# ## Load Data

# %%
# Load your data here
dm = DataManager()
df = dm.load('../data/processed/cleaned_data.csv')
df.head()
# Out:
# 📂 File: cleaned_data.csv
# 🔍 Detected encoding: ascii (100.0%)
# ✅ Loaded 546 rows × 13 columns
#    indexcore    price  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0          1  42000.0     5850         3        1        2      yes      no
# 1          2  38500.0     4000         2        1        1      yes      no
# 2          3  49500.0     3060         3        1        1      yes      no
# 3          4  60500.0     6650         3        1        2      yes     yes
# 4          5  61000.0     6360         2        1        1      yes      no
#
#   fullbase gashw airco  garagepl prefarea
# 0      yes    no    no         1       no
# 1       no    no    no         0       no
# 2       no    no    no         0       no
# 3       no    no    no         0       no
# 4       no    no    no         0       no

# %%
v = Visualizer()
v.correlation_heatmap(df,save_path="../reports/figures/correlation_heatmap.png")
# Out:
# ✅ Figure saved: ..\reports\figures\correlation_heatmap.png

# %%
fe = FeatureEngineer()
fe.aggregated_features(df,group_cols=['bedrooms', 'bathrms','stories', 'lotsize'], agg_col=['price'],agg_funcs=['mean', 'sum', 'count', 'max'])
# Out:
# ✅ Created 4 aggregated features for '['price']'
#      indexcore     price  lotsize  bedrooms  bathrms  stories driveway  \
# 0            1   42000.0     5850         3        1        2      yes
# 1            2   38500.0     4000         2        1        1      yes
# 2            3   49500.0     3060         3        1        1      yes
# 3            4   60500.0     6650         3        1        2      yes
# 4            5   61000.0     6360         2        1        1      yes
# ..         ...       ...      ...       ...      ...      ...      ...
# 541        542   91500.0     4800         3        2        4      yes
# 542        543   94000.0     6000         3        2        4      yes
# 543        544  103000.0     6000         3        2        4      yes
# 544        545  105000.0     6000         3        2        2      yes
# 545        546  105000.0     6000         3        1        2      yes
#
# ...

# %%
v.scatter_matrix(df,exclude=['indexcore'],save_path="../reports/figures/scatter_matrix.png")
# Out:
# ✅ Figure saved: ..\reports\figures\scatter_matrix.png
